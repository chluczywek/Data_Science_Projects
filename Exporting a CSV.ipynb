# %%
import bs4

from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup
from urllib.request import Request
from time import sleep
from requests import get

pages = [Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=2', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=3', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=4', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=5', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=6', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=7', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=8', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=9', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=10', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=11', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=12', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=13', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=14', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=15', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=16', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=17', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=18', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=19', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=20', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=21', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=22', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=23', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=24', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=25', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=26', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=27', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=28', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=29', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=30', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=31', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=32', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=33', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=34', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=35', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=36', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=37', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=38', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=39', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=40', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=41', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=42', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=43', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=44', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=45', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=46', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=47', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=48', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=49', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=50', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=51', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=52', headers={'User-Agent': 'Mozilla/5.0'}),
        Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc&sf_paged=53', headers={'User-Agent': 'Mozilla/5.0'})]
#my_url = Request('https://www.allhorror.com/subgenre/campy?order=release_date&order_dir=asc', headers={'User-Agent': 'Mozilla/5.0'})

titles = []
imdb_ratings = []
years = []
genres = []

for page in pages:
    uClient = uReq(page)
    page_html = uClient.read()
    uClient.close()    

    page_soup = BeautifulSoup(page_html, 'html.parser')

    containers = page_soup.findAll('li', {"class": "row"})


    
    for container in containers:
        
        my_str = container.div.a.img['alt']
        
        # Full Movie Exception
        full_movie = my_str.replace('Full Movie', '')
        table = str.maketrans(dict.fromkeys("()"))
        title = full_movie.translate(table)
        
        # Scrape the title
        the_title = title[:-5]
        titles.append(the_title)
        
        # Scrape the year
        word_list = title.split()
        year = word_list[-1]
        years.append(year)
        
        #Scrape the genre
        free = container.findAll('li')
        genre_text = free[0].text
        sep = '|'
        genre = genre_text.split(sep, 1)[0]
        genres.append(genre)
    
        rating_container = container.findAll('li')
               
         # Scrape the IMDB rating
        imdb_rating = rating_container[2].text
        imdb_ratings.append(imdb_rating)
    
        #records.append((title, rt_rating, imdb_rating))
    sleep(10)

# %%
import pandas as pd
movie_ratings = pd.DataFrame({'title': titles,
'year': years, 
'imdb': imdb_ratings,
'genre': genres                              
})
print(movie_ratings.info())
movie_ratings.head(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-162045c07966> in <module>
#       1 import pandas as pd
# ----> 2 movie_ratings = pd.DataFrame({'title': titles,
#       3 'year': years,
#       4 'imdb': imdb_ratings,
#       5 'genre': genres
#
# NameError: name 'titles' is not defined

# %%
movie_rating['year'].unique()
# Out:
# array(['1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019'], dtype=object)

# %%
movie_rating.loc[movie_ratings['year'] == '1990h']
#movie_ratings.loc[21, 'year']
# Out:
#     title  year  imdb genre
# 314  1990  1990  1990  1990

# %%
campy_movies = movie_ratings[movie_ratings.year != 'Short']

# %%
campy_movies.head(10)
# Out:
#                                                title  year   imdb  \
# 0    Half Human: The Story of the Abominable Snowman  1958    2.9
# 1                            Plan 9 from Outer Space  1959    4.0
# 2                        The Phantom of the Operetta  1960    6.8
# 3                                     Mr. Sardonicus  1961    6.7
# 4                            House on Bare Mountain   1962    4.1
# 5                               House of the Frights  1963    5.0
# 6                                 The Old Dark House  1963    5.4
# 7  The Incredibly Strange Creatures Who Stopped L...  1964    2.2
# 8                                   The Flesh Eaters  1964    6.0
# 9            The Wrestling Women vs. the Aztec Mummy  1964    3.9
#
#                                                genre
# 0                               Creatures, Thriller
# 1  Aliens, Classic, Classic Sci-Fi, Featured Clas...
# 2                                            Comedy
# ...

# %%
#Get rid of '1990h'
campy_movies.loc[314, 'year'].replace('h', '')
# Out:
# '1990'

# %%
campy_movies.loc[314, 'year'] = campy_movies.loc[314, 'year'].replace('h', '')
# Out:
# C:\Users\Master Bustache\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
campy_movies['year'].unique()
# Out:
# array(['1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019'], dtype=object)

# %%
campy_movies.loc[:, 'year'] = campy_movies['year'].astype(int)

# %%
campy_movies
# Out:
#                                                  title  year   imdb  \
# 0      Half Human: The Story of the Abominable Snowman  1958    2.9
# 1                              Plan 9 from Outer Space  1959    4.0
# 2                          The Phantom of the Operetta  1960    6.8
# 3                                       Mr. Sardonicus  1961    6.7
# 4                              House on Bare Mountain   1962    4.1
# 5                                 House of the Frights  1963    5.0
# 6                                   The Old Dark House  1963    5.4
# 7    The Incredibly Strange Creatures Who Stopped L...  1964    2.2
# 8                                     The Flesh Eaters  1964    6.0
# 9              The Wrestling Women vs. the Aztec Mummy  1964    3.9
# 10                     The Beach Girls and the Monster  1965    2.9
# 11                 The Monsters Crash the Pajama Party  1965    5.1
# 12                                      Psycho a Go-Go  1965    2.9
# ...

# %%
campy_movies.loc[:, 'imdb'] = campy_movies.loc[:, 'imdb'].replace('  N/A', '0')

# %%
campy_movies.loc[:, 'imdb'] = campy_movies.loc[:, 'imdb'].str.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-270-658bf58f4617> in <module>
# ----> 1 campy_movies.loc[:, 'imdb'] = campy_movies.loc[:, 'imdb'].str.strip()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
# ...

# %%
campy_movies.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2bf7b3031732> in <module>
# ----> 1 campy_movies.head()
#
# NameError: name 'campy_movies' is not defined

# %%
campy_movies.loc[:, 'imdb'] = campy_movies['imdb'].astype(float)

# %%
movie_ratings['imdb'].head(3)
# Out:
# 0      2.9
# 1      4.0
# 2      6.8
# Name: imdb, dtype: object

# %%
campy_movies.describe().loc[['min', 'max'], ['imdb']]
# Out:
#      imdb
# min   0.0
# max   8.1

# %%
campy_movies['n_imdb'] = campy_movies['imdb'] * 10
campy_movies.head(3)
# Out:
# C:\Users\Master Bustache\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                              title  year  imdb  \
# 0  Half Human: The Story of the Abominable Snowman  1958   2.9
# 1                          Plan 9 from Outer Space  1959   4.0
# 2                      The Phantom of the Operetta  1960   6.8
#
#                                                genre  n_imdb
# 0                               Creatures, Thriller     29.0
# 1  Aliens, Classic, Classic Sci-Fi, Featured Clas...    40.0
# 2                                            Comedy     68.0

# %%
campy_movies.to_csv('campy_movies.csv')

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (16,4))
ax1, ax2, ax3 = fig.axes
ax1.hist(campy_movies['imdb'], bins = 10, range = (0,10)) # bin range = 1
ax1.set_title('IMDB rating')

for ax in fig.axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b6b53b6412fe> in <module>
#       3 fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (16,4))
#       4 ax1, ax2, ax3 = fig.axes
# ----> 5 ax1.hist(campy_movies['imdb'], bins = 10, range = (0,10)) # bin range = 1
#       6 ax1.set_title('IMDB rating')
#       7
#
# NameError: name 'campy_movies' is not defined

# %%
ax2.hist(movie_ratings['metascore'], bins = 10, range = (0,100)) # bin range = 10
ax2.set_title('Metascore')
ax3.hist(movie_ratings['n_imdb'], bins = 10, range = (0,100), histtype = 'step')
ax3.hist(movie_ratings['metascore'], bins = 10, range = (0,100), histtype = 'step')
ax3.legend(loc = 'upper left')
ax3.set_title('The Two Normalized Distributions')
